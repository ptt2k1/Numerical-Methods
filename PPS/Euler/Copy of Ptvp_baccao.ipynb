# %%
from sympy import *
import numpy as np
import math
from pylab import *
import matplotlib.pyplot as plt

# %%
x0 = 0
X = 1
h = 0.1
m = 2
n = int((X-x0)/h)
y = np.zeros(n+1, dtype= float)
y[0] = 2  #y(0) = 2
y[1] = 1  #y'(0) = 1
def H(x,f = np.zeros(n+1, dtype= float)):
  return -2 * f[0] - 2 * f[1] # y''= -2y'-2y
def G(x):
  return math.exp(-x)*(2*cos(x) + 3*sin(x))

# %%
def Eulerhien_baccao(x0,X,h,y,m):
  n = int((X-x0)/h)
  a = np.zeros(n+1, dtype= float)
  a1 = np.zeros(n+1, dtype= float)
  z = np.zeros(n+1, dtype= float)
  x=x0
  z = y
  for i in range(n+1):
    a[i] = z[0]
    for j in range(m-1):
      z[j] = z[j] + h*z[j+1]
    z[m-1] = z[m-1] + h *H(x,z)
    x = x+h
  print(" \n   x                    y                  g(x)              ss")
  for i in range(n+1):
    a1[i] = x0 + i*h
    print("%-7.6f   %-7.6f  %-7.6f  %-7.6f \n" %(a1[i],a[i],G(a1[i]),math.fabs(G(a1[i]) - a[i]))) 
  plt.plot(a1,a,'r', label = 'Y')
    #plt.plot(a1,G(a1),'g', label = 'G')
  plt.legend()
  plt.show() 
Eulerhien_baccao(x0,X,h,y,m)
# Out:
#
#    x                    y                  g(x)              ss
# 0.000000   2.000000  2.000000  0.000000
#
# 0.100000   2.100000  2.071633  0.028367
#
# 0.200000   2.138000  2.092791  0.045209
#
# 0.300000   2.125640  2.072242  0.053398
#
# 0.400000   2.073239  2.017916  0.055323
#
# 0.500000   1.989854  1.936920  0.052933
#
# 0.600000   1.883348  1.835555  0.047794
#
# 0.700000   1.760477  1.719346  0.041131
#
# 0.800000   1.626970  1.593088  0.033883
#
# 0.900000   1.487626  1.460886  0.026739
#
# 1.000000   1.346398  1.326212  0.020186

# %%
def Hinh_thangvpbc(x0,X,h,y,m):
  n = int((X-x0)/h)
  a = np.zeros(n+1, dtype= float)
  a1 = np.zeros(n+1, dtype= float)
  z = np.zeros(n+1, dtype= float)
  z1 = np.zeros(n+1, dtype= float)
  z2 = np.zeros(n+1, dtype= float)
  x=x0
  z=y
  for i in range(n+1):
    a[i] = z[0]
    for j in range(m-1):
      z2[j] = z[j] + h*z[j+1]
    z2[m-1] = z[m-1] + h *H(x,z)
    for j in range(m-1):
      z1[j] = z[j] + 1/2*h*(z[j+1] + z2[j+1])
    z1[m - 1] = z[m - 1] + 1/2 * h * (H(x, z) + H(x + h, z2))
    x = x+h
    z = z1
  print(" \n   x                    y                  g(x)              ss")
  for i in range(n+1):
    a1[i] = x0 + i*h
    print("%-7.6f   %-7.6f  %-7.6f  %-7.6f \n" %(a1[i],a[i],G(a1[i]),math.fabs(G(a1[i]) - a[i])))  
Hinh_thangvpbc(x0,X,h,y,m)
# Out:
#
#    x                    y                  g(x)              ss
# 0.000000   1.206487  2.000000  0.793513
#
# 0.100000   1.071970  2.071633  0.999663
#
# 0.200000   0.942519  2.092791  1.150273
#
# 0.300000   0.820720  2.072242  1.251522
#
# 0.400000   0.707318  2.017916  1.310598
#
# 0.500000   0.602762  1.936920  1.334159
#
# 0.600000   0.507255  1.835555  1.328300
#
# 0.700000   0.420800  1.719346  1.298546
#
# 0.800000   0.343232  1.593088  1.249856
#
# 0.900000   0.274259  1.460886  1.186627
#
# 1.000000   0.213490  1.326212  1.112722
